# %% [markdown]
# <a href="https://colab.research.google.com/github/moyaelgabry-coder/Word-Teacher/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report
from sklearn.tree import DecisionTreeClassifier

# %%
# !unzip /content/titanic.zip

# %%
train_data = pd.read_csv('/content/train.csv')
test_data = pd.read_csv('/content/test.csv')

# %%
train_data.head(10)

# %%
train_data.shape

# %%
train_data.info()

# %%
print(train_data.isnull().sum())

# %% [markdown]
# fill missing values

# %%
train_data['Age']=train_data['Age'].fillna(train_data['Age'].median())

# %%
train_data = train_data.drop(columns='Cabin', axis=1)

# %%
print(train_data['Embarked'].mode())

# %%
train_data['Embarked']= train_data['Embarked'].fillna('S')

# %%
print(train_data.isnull().sum())

# %% [markdown]
# Visulaization

# %%
train_data['Survived'].value_counts()

# %%
sns.set()

# %%
sns.countplot(x='Survived', data=train_data)

# %%
train_data['Sex'].value_counts()

# %%
sns.countplot(x='Sex', data=train_data)

# %%
sns.countplot(x='Survived', hue='Sex', data=train_data)

# %%
train_data['Pclass'].value_counts()

# %%
sns.countplot(x='Pclass', hue='Survived', data= train_data)

# %% [markdown]
# [link text](https:// [link text](https://))Encoding by replace

# %% [markdown]
# train_data.head()

# %%
train_data.replace({'Sex':{'male':0,'female':1}, 'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
train_data.head()

# %%
x= train_data.drop(columns=['Survived','PassengerId','Name','Ticket'],axis=1)
y=train_data['Survived']

# %%
x.head()

# %%
y.head()

# %% [markdown]
# Modeling using: Logistic Regression

# %%
model = LogisticRegression()

# %%
model.fit(x,y)

# %%
train_predict = model.predict(x)
accuracy= accuracy_score(y, train_predict)
print(f"accuracy: {accuracy}")

# %%
print(classification_report(y,train_predict))

# %%
Model=DecisionTreeClassifier()

# %%
Model.fit(x,y)

# %%
tree_train=Model.predict(x)
tree_accuracy = accuracy_score(y,tree_train)
print(f"accuracy: {tree_accuracy}")

# %%
print(classification_report(y,tree_train))

# %%
test_data =test_data.drop(columns=['PassengerId','Name','Ticket','Cabin'],axis=1)

# %%
test_data.replace({'Sex':{'male':0,'female':1}, 'Embarked':{'S':0,'C':1,'Q':2}}, inplace=True)

# %%
test_data.head()

# %%
label_map = {
    0: "Did not Survive",
    1: "Survived"
}

# Reverse mapping (text → number)
Sex_map = {
    "male": 0,
    "female": 1
}

Embarked_map = {
    "cherbourg": 1,
    "queenstown": 2,
    "southampton": 0
}

# Collect user input
Pclass = int(input("Enter class (1, 2, 3): "))
Sex_input = input("Enter sex (Male/Female): ").lower()
Embarked_input = input("Enter embarked (Cherbourg/Queenstown/Southampton): ").lower()
Age = float(input("Enter age: "))
SibSp = float(input("Enter Sibling/Spouse count: "))
Parch = float(input("Enter Parent/Child count: "))
Fare = float(input("Enter fare: "))

# Convert text to numeric
Sex = Sex_map.get(Sex_input)
Embarked = Embarked_map.get(Embarked_input)

# Check for invalid input
if Sex is None:
    print("Invalid sex entered!")
    exit()

if Embarked is None:
    print("Invalid embarked location entered!")
    exit()

# Prepare input for model
input_data = np.array([[Pclass, Sex, Age, SibSp, Parch, Fare, Embarked]])

# Make prediction
prediction = Model.predict(input_data)[0]

# Print results
print("\n🚢 Titanic Survival Prediction:")
print("--------------------------------")
print(f"Class: {Pclass}")
print(f"Sex: {Sex_input}")
print(f"Age: {Age}")
print(f"SibSp: {SibSp}")
print(f"Parch: {Parch}")
print(f"Fare: {Fare}")
print(f"Embarked: {Embarked_input}")
print("--------------------------------")
print(f"Prediction: {label_map[prediction]}")
